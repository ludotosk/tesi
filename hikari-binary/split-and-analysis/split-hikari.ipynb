# %%
import pandas as pd

# %%
ds = pd.read_csv('../../datasets/HIKARI-2021/ALLFLOWMETER_HIKARI2021.csv', index_col='Unnamed: 0')
ds.head()
# Out:
#             Unnamed: 0.1                 uid        originh  originp  \
# Unnamed: 0
# 0                      0   Cg61Jch3vdz9DBptj  103.255.15.23    13316
# 1                      1   CdRIlqLWdj35Y9vW9  103.255.15.23    13318
# 2                      2   CLzp9Khd0Y09Qkgrg  103.255.15.23    13320
# 3                      3  Cnf1YA4iLB4CSNWB88  103.255.15.23    13322
# 4                      4  C4ZKvv3fpO72EAOsJ6  103.255.15.23    13324
#
#                     responh  responp  flow_duration  fwd_pkts_tot  \
# Unnamed: 0
# 0           128.199.242.104      443       2.207588            15
# 1           128.199.242.104      443      15.624266            15
# 2           128.199.242.104      443      12.203357            14
# 3           128.199.242.104      443       9.992448            14
# 4           128.199.242.104      443       7.780611            14
#
#             bwd_pkts_tot  fwd_data_pkts_tot  ...      idle.min      idle.max  \
# ...

# %%
# Create an empty list to store individual DataFrames
individual_dfs = []

# Initialize variables to keep track of the start and end indices for each DataFrame
start_index = 0

for i in range(len(ds)):
    if ds.index.get_level_values(0)[i] == 0:
        # If the value in the specified index column is 0, create a new DataFrame
        individual_dfs.append(ds.iloc[start_index:i])
        start_index = i + 1

# Append the last DataFrame
individual_dfs.append(ds.iloc[start_index:])

# %%
len(individual_dfs)
# Out:
# 6

# %%
for i in range(1,6):
    print(individual_dfs[i].shape)
# Out:
# (5144, 87)
# (5883, 87)
# (170150, 87)
# (347430, 87)
# (26666, 87)

# %%
for i in range(1,6):
    file_name = 'ds_' + str(i) + '.csv'
    individual_dfs[i].to_csv(file_name)
