# %%
import duckdb

# %%
ds = duckdb.read_csv('../datasets/CSECICIDS2018_improved/*.csv')
ds
# Out:
# ┌───────┬──────────────────────┬────────────────┬───┬───────────┬─────────────────────┬─────────┬────────────────────┐
# │  id   │       Flow ID        │     Src IP     │ … │ ICMP Type │ Total TCP Flow Time │  Label  │ Attempted Category │
# │ int64 │       varchar        │    varchar     │   │   int64   │        int64        │ varchar │       int64        │
# ├───────┼──────────────────────┼────────────────┼───┼───────────┼─────────────────────┼─────────┼────────────────────┤
# │     1 │ 172.31.66.11-23.15…  │ 172.31.66.11   │ … │        -1 │           110588280 │ BENIGN  │                 -1 │
# │     2 │ 172.31.66.11-23.52…  │ 172.31.66.11   │ … │        -1 │           117631936 │ BENIGN  │                 -1 │
# │     3 │ 172.31.66.11-72.21…  │ 172.31.66.11   │ … │        -1 │           117577955 │ BENIGN  │                 -1 │
# │     4 │ 172.31.66.11-108.1…  │ 172.31.66.11   │ … │        -1 │           117112683 │ BENIGN  │                 -1 │
# ...

# %%
ds.describe()
