# %%
import duckdb
import pandas as pd
import numpy as np

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///cescicids2018.db

# %%
ds = duckdb.sql("SELECT 'Flow ID' AS ID, Label FROM read_csv_auto('../datasets/CSECICIDS2018_improved/*.csv')").to_df()
ds

# %%
Labels = pd.unique(ds['Label'])
Labels
# Out:
# array(['BENIGN', 'Web Attack - Brute Force', 'Web Attack - XSS',
#        'Web Attack - SQL', 'Web Attack - Brute Force - Attempted',
#        'Web Attack - XSS - Attempted', 'Web Attack - SQL - Attempted',
#        'Botnet Ares - Attempted', 'Botnet Ares',
#        'DDoS-LOIC-UDP - Attempted', 'DDoS-LOIC-UDP', 'DDoS-HOIC',
#        'Infiltration - NMAP Portscan', 'Infiltration - Dropbox Download',
#        'Infiltration - Dropbox Download - Attempted',
#        'Infiltration - Communication Victim Attacker', 'DoS GoldenEye',
#        'DoS GoldenEye - Attempted', 'DoS Slowloris',
#        'DoS Slowloris - Attempted', 'DDoS-LOIC-HTTP',
#        'FTP-BruteForce - Attempted', 'DoS Hulk', 'DoS Hulk - Attempted',
#        'SSH-BruteForce'], dtype=object)

# %%
np.random.choice(ds[''Flow ID''], 10)
# Out:
#   Cell In[16], line 1
#     np.random.choice(ds[''Flow ID''], 10)
#                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
datasets = []

for label in Labels:
    print(label)
# Out:
# BENIGN
# Web Attack - Brute Force
# Web Attack - XSS
# Web Attack - SQL
# Web Attack - Brute Force - Attempted
# Web Attack - XSS - Attempted
# Web Attack - SQL - Attempted
# Botnet Ares - Attempted
# Botnet Ares
# DDoS-LOIC-UDP - Attempted
# DDoS-LOIC-UDP
# DDoS-HOIC
# Infiltration - NMAP Portscan
# Infiltration - Dropbox Download
# Infiltration - Dropbox Download - Attempted
# Infiltration - Communication Victim Attacker
# DoS GoldenEye
# DoS GoldenEye - Attempted
# DoS Slowloris
# DoS Slowloris - Attempted
# DDoS-LOIC-HTTP
# FTP-BruteForce - Attempted
# DoS Hulk
# DoS Hulk - Attempted
# SSH-BruteForce

# %%
counted_labels = duckdb.sql("SELECT Label, count(Label) AS count FROM read_csv_auto('../datasets/CSECICIDS2018_improved/*.csv') GROUP BY Label ORDER BY count(Label) DESC").to_df()
counted_labels
# Out:
#                                            Label     count
# 0                                         BENIGN  59353486
# 1                                       DoS Hulk   1803160
# 2                                      DDoS-HOIC   1082293
# 3                     FTP-BruteForce - Attempted    298874
# 4                                 DDoS-LOIC-HTTP    289328
# 5                                    Botnet Ares    142921
# 6                                 SSH-BruteForce     94197
# 7                   Infiltration - NMAP Portscan     89374
# 8                                  DoS GoldenEye     22560
# 9                                  DoS Slowloris      8490
# 10                     DoS GoldenEye - Attempted      4301
# 11                                 DDoS-LOIC-UDP      2527
# 12                     DoS Slowloris - Attempted      2280
# 13                       Botnet Ares - Attempted       262
# 14                     DDoS-LOIC-UDP - Attempted       251
# ...

# %%
! head "../datasets/CSECICIDS2018_improved/Friday-02-03-2018.csv" -n 1
# Out:
# id,Flow ID,Src IP,Src Port,Dst IP,Dst Port,Protocol,Timestamp,Flow Duration,Total Fwd Packet,Total Bwd packets,Total Length of Fwd Packet,Total Length of Bwd Packet,Fwd Packet Length Max,Fwd Packet Length Min,Fwd Packet Length Mean,Fwd Packet Length Std,Bwd Packet Length Max,Bwd Packet Length Min,Bwd Packet Length Mean,Bwd Packet Length Std,Flow Bytes/s,Flow Packets/s,Flow IAT Mean,Flow IAT Std,Flow IAT Max,Flow IAT Min,Fwd IAT Total,Fwd IAT Mean,Fwd IAT Std,Fwd IAT Max,Fwd IAT Min,Bwd IAT Total,Bwd IAT Mean,Bwd IAT Std,Bwd IAT Max,Bwd IAT Min,Fwd PSH Flags,Bwd PSH Flags,Fwd URG Flags,Bwd URG Flags,Fwd RST Flags,Bwd RST Flags,Fwd Header Length,Bwd Header Length,Fwd Packets/s,Bwd Packets/s,Packet Length Min,Packet Length Max,Packet Length Mean,Packet Length Std,Packet Length Variance,FIN Flag Count,SYN Flag Count,RST Flag Count,PSH Flag Count,ACK Flag Count,URG Flag Count,CWR Flag Count,ECE Flag Count,Down/Up Ratio,Average Packet Size,Fwd Segment Size Avg,Bwd Segment Size Avg,Fwd Byte
# ...

# %%
# %sql SELECT Label, count(Label) FROM read_csv_auto('../datasets/CSECICIDS2018_improved/*.csv') GROUP BY Label ORDER BY count(Label) DESC;
# Out:
#                                            Label  count("Label")
# 0                                         BENIGN        59353486
# 1                                       DoS Hulk         1803160
# 2                                      DDoS-HOIC         1082293
# 3                     FTP-BruteForce - Attempted          298874
# 4                                 DDoS-LOIC-HTTP          289328
# 5                                    Botnet Ares          142921
# 6                                 SSH-BruteForce           94197
# 7                   Infiltration - NMAP Portscan           89374
# 8                                  DoS GoldenEye           22560
# 9                                  DoS Slowloris            8490
# 10                     DoS GoldenEye - Attempted            4301
# 11                                 DDoS-LOIC-UDP            2527
# 12                     DoS Slowloris - Attempted            2280
# ...

# %%
# %sql CREATE VIEW v1 AS SELECT Label, ROW_NUMBER() OVER (PARTITION BY Label ORDER BY NEWID()) AS RowNum FROM read_csv_auto('../datasets/CSECICIDS2018_improved/*.csv');
# Out:
# RuntimeError: (duckdb.duckdb.CatalogException) Catalog Error: Scalar Function with name newid does not exist!
# Did you mean "now"?
# [SQL: CREATE VIEW v1 AS SELECT Label, ROW_NUMBER() OVER (PARTITION BY Label ORDER BY NEWID()) AS RowNum FROM read_csv_auto('../datasets/CSECICIDS2018_improved/*.csv');]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %sql SELECT Label FROM read_csv_auto('../datasets/CSECICIDS2018_improved/*.csv') ORDER BY RANDOM() LIMIT 2000;
# Out:
#          Label
# 0       BENIGN
# 1       BENIGN
# 2       BENIGN
# 3     DoS Hulk
# 4       BENIGN
# ...        ...
# 1995    BENIGN
# 1996    BENIGN
# 1997    BENIGN
# 1998    BENIGN
# 1999    BENIGN
#
# [2000 rows x 1 columns]

# %%
# %sql SELECT Label, count(Label) FROM read_csv_auto('../datasets/CICIDS2017_improved/*.csv') GROUP BY Label ORDER BY count(Label) DESC;
# Out:
#                                      Label  count("Label")
# 0                                   BENIGN         1582566
# 1                                 Portscan          159066
# 2                                 DoS Hulk          158468
# 3                                     DDoS           95144
# 4                  Infiltration - Portscan           71767
# 5                            DoS GoldenEye            7567
# 6                       Botnet - Attempted            4067
# 7                              FTP-Patator            3972
# 8                            DoS Slowloris            3859
# 9             DoS Slowhttptest - Attempted            3368
# 10                             SSH-Patator            2961
# 11               DoS Slowloris - Attempted            1847
# 12                        DoS Slowhttptest            1740
# 13    Web Attack - Brute Force - Attempted            1292
# 14                                  Botnet             736
# ...
