# %%
import pandas as pd
import pickle

# %%
with open('HIKARI-2021/ALLFLOWMETER_HIKARI2021.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data.head()
# Out:
#    Unnamed: 0                 uid        originh  originp          responh  \
# 0           0   Cg61Jch3vdz9DBptj  103.255.15.23    13316  128.199.242.104
# 1           1   CdRIlqLWdj35Y9vW9  103.255.15.23    13318  128.199.242.104
# 2           2   CLzp9Khd0Y09Qkgrg  103.255.15.23    13320  128.199.242.104
# 3           3  Cnf1YA4iLB4CSNWB88  103.255.15.23    13322  128.199.242.104
# 4           4  C4ZKvv3fpO72EAOsJ6  103.255.15.23    13324  128.199.242.104
#
#    responp  flow_duration  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  ...  \
# 0      443       2.207588            15            14                  6  ...
# 1      443      15.624266            15            14                  6  ...
# 2      443      12.203357            14            13                  6  ...
# 3      443       9.992448            14            13                  6  ...
# 4      443       7.780611            14            14                  6  ...
#
# ...

# %%
ds = pd.read_csv('HIKARI-2021/ALLFLOWMETER_HIKARI2021.csv')
ds.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                 uid        originh  originp  \
# 0             0           0   Cg61Jch3vdz9DBptj  103.255.15.23    13316
# 1             1           1   CdRIlqLWdj35Y9vW9  103.255.15.23    13318
# 2             2           2   CLzp9Khd0Y09Qkgrg  103.255.15.23    13320
# 3             3           3  Cnf1YA4iLB4CSNWB88  103.255.15.23    13322
# 4             4           4  C4ZKvv3fpO72EAOsJ6  103.255.15.23    13324
#
#            responh  responp  flow_duration  fwd_pkts_tot  bwd_pkts_tot  ...  \
# 0  128.199.242.104      443       2.207588            15            14  ...
# 1  128.199.242.104      443      15.624266            15            14  ...
# 2  128.199.242.104      443      12.203357            14            13  ...
# 3  128.199.242.104      443       9.992448            14            13  ...
# 4  128.199.242.104      443       7.780611            14            14  ...
#
#        idle.min      idle.max      idle.tot      idle.avg  idle.std  \
# ...

# %%
ds = pd.read_csv('HIKARI-2021/ALLFLOWMETER_HIKARI2021.csv', index_col=0)
ds.head()
# Out:
#    Unnamed: 0                 uid        originh  originp          responh  \
# 0           0   Cg61Jch3vdz9DBptj  103.255.15.23    13316  128.199.242.104
# 1           1   CdRIlqLWdj35Y9vW9  103.255.15.23    13318  128.199.242.104
# 2           2   CLzp9Khd0Y09Qkgrg  103.255.15.23    13320  128.199.242.104
# 3           3  Cnf1YA4iLB4CSNWB88  103.255.15.23    13322  128.199.242.104
# 4           4  C4ZKvv3fpO72EAOsJ6  103.255.15.23    13324  128.199.242.104
#
#    responp  flow_duration  fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  ...  \
# 0      443       2.207588            15            14                  6  ...
# 1      443      15.624266            15            14                  6  ...
# 2      443      12.203357            14            13                  6  ...
# 3      443       9.992448            14            13                  6  ...
# 4      443       7.780611            14            14                  6  ...
#
# ...

# %%
len(ds[ds['Unnamed: 0'] == 0])
# Out:
# 5

# %% [markdown]
# Hello,
# thank you for answering me I was referring to the first article which I mentioned on the object of the email.
#
# Anyway, I read the second article and I have some concerns about it Unnamed: 0.1 is not a feature of the dataset, is created by pandas if you don't tell pandas that the first column is the index. In fact the author of Hikari talk about having 86 features, but if you count Unnamed: 0.1 and Unnamed: 0 they are 88 not 86. If you want to check try to load the pickle file given by the author and you will notice that Unnamed: 0.1 is not there, even by opening the CSV file with Excel you can see that the column is not there. Moreover, Unnamed: 0 not only is not a feature but is the index of the single CSV that they merged together to make the final CSV. That is because they made a CSV for each pcap and then they merged together.
